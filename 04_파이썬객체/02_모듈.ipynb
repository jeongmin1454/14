# %%
import module1

print(module1.add(3, 4))
print(module1.sub(5, 2))
# Out:
# 7
# 3

# %%
from module1 import add, sub
# from module1 import *         # 안에 있는 모든것을 가져옴, 비효율적 (메모리 많이 잡아먹나?)

print(add(10, 20))
print(sub(50, 10))
# Out:
# 30
# 40
